# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import re

# %%
#Leer CSV con los datos
df_casas = pd.read_csv('casas_idealista2.csv', sep=';', encoding='utf-16')
df_casas.head()
